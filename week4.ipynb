# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import jieba
import re
import os

# %%
def is_chinese(uchar):         
    if u'\u4e00' <= uchar<=u'\u9fff':
        return True
    else:
        return False

# %%
def one_word(word):
    if len(word)==1:
        return True
    else:
        return False

# %%
currentPath = os.getcwd()
# print(currentPath)
data = open(currentPath+"/tecoDisclosure.txt", "r", encoding="utf-8")
data = data.read()

# %%
regex = re.compile(r'[\n\r\t]')
data = regex.sub(" ", data)
data.replace(" ","")
# data
# Out:
# '-113-東元電機股份有限公司個體財務報表附註民國106年度及105年度單位：新台幣仟元(除特別註明者外)一、公司沿革東元電機股份有限公司(以下簡稱「本公司」)於民國45年6月12日依公司法設立。主要經營之業務為：各種機械設備、冷凍空調設備、發電、輸電、配電機械、電器及視聽電子產品、有線及無線通信機械器材之產銷、承裝等業務。本公司於民國92年與台安電機股份有限公司合併，本公司為存續公司，台安電機股份有限公司為消滅公司。另本公司於民國100年與安陽電機股份有限公司及東台科技股份有限公司合併，本公司為存續公司，安陽電機股份有限公司及東台科技股份有限公司為消滅公司。二、通過財務報告之日期及程序本個體財務報告已於民國107年3月26日經董事會通過發布。三、新發布及修訂準則及解釋之適用(一)已採用金融監督管理委員會(以下簡稱「金管會」)認可之新發布、修正後國際財務報導準則之影響下表彙列金管會認可之民國106年適用之國際財務報導準則之新發布、修正及修訂之準則及解釋：新發布/修正/修訂準則及解釋國際會計準則理事會發布之生效日國際財務報導準則第10號、第12號及國際會計準則第28號之修正「投資個體：適用合併報表之例外規定」民國105年1月1日國際財務報導準則第11號之修正「取得聯合營運權益之會計處理」民國105年1月1日國際財務報導準則第14號「管制遞延帳戶」民國105年1月1日國際會計準則第1號之修正「揭露倡議」民國105年1月1日國際會計準則第16號及第38號之修正「可接受之折舊及攤銷方法之闡釋」民國105年1月1日國際會計準則第16號及第41號之修正「農業：生產性植物」民國105年1月1日國際會計準則第19號之修正「確定福利計畫：員工提撥金」民國103年7月1日國際會計準則第27號之修正「單獨財務報表之權益法」民國105年1月1日國際會計準則第36號之修正「非金融資產可回收金額之揭露」民國103年1月1日國際會計準則第39號之修正「衍生工具之約務更替與避險會計之持續適用」民國103年1月1日國際財務報導解釋第21號「公課」民國103年1月1日2010-2012週期之年度改善民國103年7月1日-114-本公司經評估上述準則及解釋對本公司財務狀況與財務績效並無重大影響。(二)尚未採用金管會認可之新發布、修正後國際財務報導準則之影響下表彙列金管會認可之民國107年適用之國際財務報導準則之新發布、修正及修訂之準則及解釋：除下列所述者外，本公司經評估上述準則及解釋對本公司財務狀況與財務績效並無重大影響：1.國際財務報導準則第9號「金融工具」(1)金融資產權益工具分類為透過損益按公允價值衡量之金融資產，除非企業作不可撤銷之選擇將非交易目的之權益工具的公允價值認列於其他綜合損益。(2)金融資產債務工具之減損評估應採預期信用損失模式，於每一資產負債表日評估該工具之信用風險是否有顯著增加，以適用12個月之預期信用損失或存續期間之預期信用損失(於發生減損前之利息收入按資產帳面總額估計)；或是否業已發生減損，於發生減損後之利息收入按提列備抵呆帳後之帳面淨額估計。應收帳款(不包含重大財務組成部分)新發布/修正/修訂準則及解釋國際會計準則理事會發布之生效日2011-2013週期之年度改善民國103年7月1日2012-2014週期之年度改善民國105年1月1日新發布/修正/修訂準則及解釋國際會計準則理事會發布之生效日國際財務報導準則第2號之修正「股份基礎給付交易之分類及衡量」民國107年1月1日國際財務報導準則第4號之修正「於國際財務報導準則第4號『保險合約』下國際財務報導準則第9號『金融工具』之適用」民國107年1月1日國際財務報導準則第9號「金融工具」民國107年1月1日國際財務報導準則第15號「客戶合約之收入」民國107年1月1日國際財務報導準則第15號之修正「國際財務報導準則第15號『客戶合約之收入』之闡釋」民國107年1月1日國際會計準則第7號之修正「揭露倡議」民國106年1月1日國際會計準則第12號之修正「未實現損失之遞延所得稅資產之認列」民國106年1月1日國際會計準則第40號之修正「投資性不動產之轉列」民國107年1月1日國際財務報導解釋第22號「外幣交易與預收(付)對價」民國107年1月1日2014-2016週期之年度改善-國際財務報導準則第1號「首次採用國際財務報導準則」民國107年1月1日2014-2016週期之年度改善-國際財務報導準則第12號「對其他個體之權益之揭露」民國106年1月1日2014-2016週期之年度改善-國際會計準則第28號「投資關聯企業及合資」民國107年1月1日-115-應按存續期間之預期信用損失衡量備抵損失。2.國際財務報導準則第15號「客戶合約之收入」國際財務報導準則第15號「客戶合約之收入」取代國際會計準則第11號「建造合約」、國際會計準則第18號「收入」以及其相關解釋及解釋公告。按準則規定收入應於客戶取得對商品或勞務之控制時認列，當客戶已具有主導資產之使用並取得該資產之幾乎所有剩餘效益之能力時表示客戶取得對商品或勞務之控制。此準則之核心原則為「企業認列收入以描述對客戶所承諾之商品或勞務之移轉，該收入之金額反映該等商品或勞務換得之預期有權取得之對價」。企業按核心原則認列收入時需運用下列五步驟來決定收入認列的時點及金額：步驟1：辨認客戶合約。步驟2：辨認合約中之履約義務。步驟3：決定交易價格。步驟4：將交易價格分攤至合約中之履約義務。步驟5：於（或隨）企業滿足履約義務時認列收入。此外，準則亦包括一套整合性之揭露規定，該等規定將使企業對財務報表使用者提供有關客戶合約所產生之收入與現金流量之性質、金額、時間及不確定性之綜合資訊。3.國際財務報導準則第15號之修正「國際財務報導準則第15號『客戶合約之收入』之闡釋」此修正釐清如何辨認合約中的履約義務(即承諾移轉商品或勞務予客戶)；如何決定企業為主理人(提供商品或勞務)或代理人(負責安排商品或勞務之提供)；以及決定由授權取得之收入應於某一時點或於一段期間內認列。除上述之釐清外，此修正尚包含兩項新增的簡化規定，以降低企業首次適用新準則時之成本及複雜度。於適用金管會認可之民國107年IFRSs版本時，本公司對於國際財務報導準則第9號(以下簡稱「IFRS9」)及國際財務報導準則第15號(以下簡稱「IFRS15」)係採用簡易追溯調整，初步評估對民國107年1月1日之重大影響彙總如下，相關影響數尚待本公司最終評估結果決定：資產負債表受影響項目民國106年適用IFRSs金額版本升級影響金額民國107年適用IFRSs金額說明民國107年1月1日備供出售金融資產$6,609,115($6,609,115)$-透過其他綜合損益按公允價值衡量之金融資產-6,609,1156,609,115資產影響總計$6,609,115$-$6,609,115-116-說明：1.本集團將備供出售金融資產$6,609,115，按IFRS9分類規定，將非屬交易目的之權益工具作一個不可撤銷的選擇，調增透過其他綜合損益按公允價值衡量之金融資產$6,609,115，調減其他權益$394,039，並調增保留盈餘$394,039。2.本公司因子公司持有備供出售金融資產，按IFRS9規定重分類至透過損益按公允價值衡量之金融資產及透過其他綜合損益按公允價值衡量之金融資產，調減其他權益$274,216，並調增保留盈餘$274,216。(三)國際會計準則理事會已發布但尚未經金管會認可之國際財務報導準則之影響下表彙列國際會計準則理事會已發布但尚未納入金管會認可之國際財務報導準則之新發布、修正及修訂之準則及解釋：除下列所述者外，本公司經評估上述準則及解釋對本公司財務狀況與財務績效並無重大影響，相關影響金額待評估完成時予以揭露：1.國際財務報導準則第16號「租賃」國際財務報導準則第16號「租賃」取代國際會計準則第17號「租賃」及其相關解釋及解釋公告。此準則規定承租人應認列使用權資產及租賃負債（除租賃期間短於12個月或低價值標的資產之租賃外）；出租人會計處理仍相同，按營業租賃及融資租賃兩種類型處理，僅增加相關揭露。資產負債表受影響項目民國106年適用IFRSs金額版本升級影響金額民國107年適用IFRSs金額說明保留盈餘$22,469,336$668,255$23,137,591其他權益1,704,958(668,255)1,036,703權益影響總計$24,174,294$-$24,174,294新發布/修正/修訂準則及解釋國際會計準則理事會發布之生效日國際財務報導準則第9號之修正「具負補償之提前還款特性」民國108年1月1日國際財務報導準則第10號及國際會計準則第28號之修正「投資者與其關聯企業或合資間之資產出售或投入」待國際會計準則理事會決定國際財務報導準則第16號「租賃」民國108年1月1日國際財務報導準則第17號「保險合約」民國110年1月1日國際會計準則第19號之修正「計畫之修正、縮減或清償」民國108年1月1日國際會計準則第28號之修正「關聯企業與合資之長期權益」民國108年1月1日國際財務報導解釋第23號「不確定性之所得稅處理」民國108年1月1日2015-2017週期之年度改善民國108年1月1日-117-2.國際財務報導解釋第23號「不確定性之所得稅處理」此解釋釐清當所得稅處理存有不確定性時，企業應依據此解釋決定課稅所得(課稅損失)、課稅基礎、未使用課稅損失、未使用所得稅抵減及稅率，依國際會計準則第12號「所得稅」之規定認列及衡量其當期與遞延所得稅資產/負債。四、重大會計政策之彙總說明編製本個體財務報告所採用之主要會計政策說明如下。除另 ...

# %%
seg_list = jieba.cut(data, cut_all=False)  # 精确模式
# print("Default Mode: " + "/ ".join(seg_list))

# %%
new_data=""
for d in data:
    if is_chinese(d):
        new_data+=d

# %%
stopwords = ["集團","收入","成本","費用","工具","國際","合約","財務報導","取得",
             "股份","有限公司","年度","公司","企業","準則","民國","包含","第號","可能","解釋","支付","當現","其他","綜合","資產","負債"]

puncs = '！？｡＂＃＄％＆＇（）＊＋，－／：；＜＝＞＠［＼］＾＿｀｛｜｝～｟｠｢｣､、〃》「」『』【】〔〕〖〗〘〙〚〛〜〝〞〟〰〾〿–—‘’‛“”„‟…‧﹏.。'

addword = ["或有負債","不動產廠房及設備","馬達","無形資產","新台幣","附註","視聽","合併","東元電機","股份有限公司","財務報表","國際","國際會計準則","仟元","資產","理事會","國外營運機構","財務","所得稅","銀行",
           "績效","貨幣","表達","項目","融資","評估","財務報告","業務","生產性植物","其他","遞延","帳戶","聯合營運","揭露","財務報導","確定福利計畫","可回收金額","損益","收入","費用","客戶","合約","營運","融資",
           "換算","機構","公允價值","可靠","衡量","折現","攤銷後成本","避險會計","公司債","淨變現價值","決定","製成品","重大","設立","公司治理","租賃","承租人","歸屬","編製","負債","合併報表","備供出售","金融",
           "透過","其他","綜合","發佈","修正","機械","民國","關係人","轉投資","實收資本額","企業"]

delword = ["董致","致型","致","致致","災致","校董","董校","日月","災型","董災","災災","型型","董型","致校","校型","校致","外本","致災","綜合損","衡之融","非動","權法","及其","日止"]

for w in addword:
    jieba.add_word(w, freq=None, tag=None)
for w in delword:
    jieba.del_word(w)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/jr/jp2dd4ss0tbft8nd60g_4v7h0000gn/T/jieba.cache
# Loading model cost 0.918 seconds.
# Prefix dict has been built succesfully.

# %%
seg_list = jieba.cut(new_data, cut_all=False)
seg_list = list(seg_list)
print(seg_list)
oneWord = []
for word in seg_list:
    if one_word(word) and (word not in oneWord):
        oneWord.append(word)
print(oneWord)
# Out:
# ['東元電機', '股份有限公司', '個體', '財務報表', '附註', '民國', '及', '單位', '新台幣', '仟元', '除特', '別', '註', '明', '者', '外', '一', '公司', '沿革', '東元電機', '股份有限公司', '以下', '簡稱', '本', '公司', '於', '民國', '月', '日', '依', '公司法', '設', '主要', '經營', '之', '業務', '為', '各種', '機械', '設備', '凍空調', '設備', '發電輸', '電配電', '機械', '電器', '及', '視聽', '電子', '產品', '有線', '及', '無線', '通信', '機械', '器材', '之產銷', '承裝', '等', '業務', '本', '公司', '於', '民國', '與', '台安', '電機', '股份有限公司', '合併', '本', '公司', '為', '存續', '公司', '台安', '電機', '股份有限公司', '為', '消滅', '公司', '另本', '公司', '於', '民國', '與', '安陽', '電機', '股份有限公司', '及', '東台', '科技股份', '有限公司', '合併', '本', '公司', '為', '存續', '公司', '安陽', '電機', '股份有限公司', '及', '東台', '科技股份', '有限公司', '為', '消滅', '公司', '二通', '過', '財務報告', '之', '日期', '及', '程序', '本個體', '財務報告', '已', '於', '民國', '月', '日經', '董事', '會', '通過', '發布', '三新', '發布及', '修訂', '準則', '及', '解釋', '之', '適用', '一', '已', '採用融', '監督', '管委', '員會', '以下', '簡稱', '管會', '認可', '之', '新', '發布', '修正', '後', '國際', '財務報導', '準則', '之', '影響', '下表', '彙', '管會', '認可', '之', '民國', '適用', '之', '國際', '財務報導', '準則', '之', '新', '發布', '修正', '及', '修訂', '之', '準則', '及', '解釋', '新', '發布', '修正', '修訂', '準則', '及', '解釋', '國際會計準則', '事會', '發布', '之', '生效日', '國際', '財務報導', '準則', '第號', '第號', '及', '國際會計準則', '第號', '之', '修正', '投資個體', '適用', '合併報表', '之外', '規定', '民國', '月', '日', '國際', '財務報導', '準則', '第號', '之', '修正', '取得', '合', '營運', '權之會', '計處', '民國', '月', '日', '國際', '財務報導', '準則', '第號', '管制', '遞延', '帳戶', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '揭倡議', '民國', '月', '日', '國際會計準則', '第號', '及第', '號之', '修正', '可', '接受', '之折', '舊及', '攤銷', '方法', '之', '闡釋', '民國', '月', '日', '國際會計準則', '第號', '及第', '號之', '修正', '農業', '生產性植物', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '確定', '計畫員工', '提撥', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '單獨', '財務報表', '之權法', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '非融', '資產', '可回收', '額', '之', '揭', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '衍生', '工具', '之約務替', '與', '避險會計', '之持續', '適用', '民國', '月', '日', '國際', '財務報導', '解釋', '第號', '公課', '民國', '月', '日', '週期', '之', '改善', '民國', '月', '日本公司', '經', '評估', '上述', '準則', '及', '解釋', '對', '本', '公司', '財務', '況', '與', '財務', '績效', '並無', '重大', '影響', '二', '尚未', '採用', '管會', '認可', '之', '新', '發布', '修正', '後', '國際', '財務報導', '準則', '之', '影響', '下表', '彙', '管會', '認可', '之', '民國', '適用', '之', '國際', '財務報導', '準則', '之', '新', '發布', '修正', '及', '修訂', '之', '準則', '及', '解釋', '除', '下', '所述', '者', '外', '本', '公司', '經', '評估', '上述', '準則', '及', '解釋', '對', '本', '公司', '財務', '況', '與', '財務', '績效', '並無', '重大', '影響', '國際', '財務報導', '準則', '第號融', '工具', '融', '資產', '權', '工具', '分為', '透過', '損按', '公允價值', '衡', '之', '融', '資產', '除非', '企業', '作可', '撤銷', '之', '選擇', '將非交', '目的', '之權', '工具', '的', '公允價值', '認', '於', '其他', '綜合', '損融', '資產', '債務', '工具', '之', '減損', '評估', '應採', '預期', '信用', '損失', '模式', '於', '每', '一', '資產', '負債', '表日', '評估', '該', '工具', '之', '信用', '風險', '是否', '有', '顯著', '增加', '以', '適用', '個', '月', '之', '預期', '信用', '損失', '或', '存續', '期間', '之', '預期', '信用', '損失', '於', '發生', '減損', '前', '之息', '收入', '按', '資產', '帳面', '總額', '估計', '或', '是否', '業已', '發生', '減損', '於', '發生減', '損後之息', '收入', '按', '提備', '抵呆', '帳後之帳', '面淨額', '估計', '應收', '帳款', '包含', '重大', '財務', '組成', '部分', '新', '發布', '修正', '修訂', '準則', '及', '解釋', '國際會計準則', '事會', '發布', '之', '生效日', '週期', '之', '改善', '民國', '月', '日', '週期', '之', '改善', '民國', '月', '日', '新', '發布', '修正', '修訂', '準則', '及', '解釋', '國際會計準則', '事會', '發布', '之', '生效日', '國際', '財務報導', '準則', '第號', '之', '修正', '股份', '基礎給', '付交', '之分', '及衡', '民國', '月', '日', '國際', '財務報導', '準則', '第號', '之', '修正', '於', '國際', '財務報導', '準則', '第號', '保險', '合約', '下', '國際', '財務報導', '準則', '第號融', '工具', '之', '適用', '民國', '月', '日', '國際', '財務報導', '準則', '第號融', '工具', '民國', '月', '日', '國際', '財務報導', '準則', '第號', '客戶', '合約', '之', '收入', '民國', '月', '日', '國際', '財務報導', '準則', '第號', '之', '修正', '國際', '財務報導', '準則', '第號', '客戶', '合約', '之', '收入', '之', '闡釋', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '揭倡議', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '未實現', '損失', '之', '遞延', '所得稅', '資產', '之認', '民國', '月', '日', '國際會計準則', '第號', '之', '修正', '投資性', '動產之轉', '民國', '月', '日', '國際', '財務報導', '解釋', '第號', '外幣', '交', '與', '預', '收付', '對價', '民國', '月', '日', '週期', '之', '改善 ...
# ['及', '別', '註', '明', '者', '外', '一', '本', '於', '月', '日', '依', '設', '之', '為', '等', '與', '過', '已', '會', '新', '後', '彙', '合', '可', '額', '揭', '經', '對', '況', '二', '除', '下', '融', '權', '衡', '的', '認', '每', '該', '有', '以', '個', '或', '前', '按', '交', '預', '應', '損', '時', '並', '能', '得', '驟', '至', '隨', '約', '亦', '此', '釐', '清', '中', '承', '由', '某', '內', '尚', '項', '低', '複', '雜', '係', '簡', '總', '三', '但', '其', '短', '仍', '待', '關', '處', '確', '未', '四', '所', '另', '在', '地', '基', '均', '即', '匯', '性', '非', '同', '和', '因', '當', '分', '則', '屬', '動', '週', '而', '現', '將', '無', '指', '甚', '小', '上', '被', '八', '就', '續', '多', '步', '使', '迴', '間', '再', '自', '收', '孰', '製', '品', '原', '造', '惟', '比', '很', '法', '且', '款', '型', '接', '讓', '如', '據', '攤', '才', '獨', '態', '限', '改', '舊', '主', '象', '較', '是', '辨', '從', '受', '贖', '太', '買', '互', '歸', '墊', '去', '需', '賺', '員', '差', '入', '向', '嗣', '估', '發', '銷', '售', '各', '種', '管', '提', '務', '完', '止', '占', '期', '高', '淨', '假', '請', '然', '供', '信', '銀', '詳', '櫃', '進', '天', '沖', '群', '七', '五', '甲', '乙', '丙', '丁', '戊', '己', '庚', '辛', '壬', '癸', '丑', '德', '股', '達', '仟', '藏', '表', '值', '含', '減', '失', '風', '電', '息', '託', '租', '保', '償', '長', '十', '訂', '薪', '臺', '變', '予', '制', '人', '取', '開', '訖', '通', '存', '憑', '兌', '辦', '贈', '用', '虧', '撥', '派', '元', '鑑', '轉', '賠', '獲', '站', '貨', '徵', '廢', '潛', '加', '蘇', '馬', '悅', '諮', '式', '台', '堃', '霖', '凍', '正', '機', '子', '盛', '米', '雅', '光', '迪', '位', '縣', '鄉', '他', '備', '批', '押', '九', '佔', '相', '資', '部', '密', '賣', '幣', '具', '美', '往', '好', '級', '重', '調', '質', '帳', '藉', '貼', '近', '乘', '愈', '出', '大']

# %%
wordDict = {}
for w in seg_list:
    if (w not in stopwords) and (w not in puncs) and (w not in oneWord):
        if w in wordDict:
            wordDict[w] = wordDict[w] + 1
        else:
            wordDict[w] = 1
ten = sorted(wordDict.items(), key=lambda x: x[1],reverse = True)
ten
# Out:
# [('公允價值', 112),
#  ('所得稅', 76),
#  ('重大', 54),
#  ('影響', 49),
#  ('子公司', 48),
#  ('投資', 45),
#  ('財務', 44),
#  ('借款', 44),
#  ('工程', 42),
#  ('退休', 40),
#  ('減損', 38),
#  ('損失', 38),
#  ('相關', 38),
#  ('新台幣', 37),
#  ('採用', 37),
#  ('如下', 37),
#  ('認為', 37),
#  ('風險', 36),
#  ('當期', 36),
#  ('修正', 35),
#  ('項目', 34),
#  ('設備', 33),
#  ('部分', 32),
#  ('關係人', 32),
#  ('國際會計準則', 31),
#  ('透過', 31),
#  ('估計', 31),
#  ('持有', 31),
#  ('遞延', 30),
#  ('分別', 30),
#  ('東元', 30),
#  ('衍生', 29),
#  ('評估', 29),
#  ('評價', 29),
#  ('控制', 28),
#  ('變動', 28),
#  ('到期', 27),
#  ('發生', 26),
#  ('貨幣', 26),
#  ('股份有限公司', 25),
#  ('市場', 25),
#  ('應付', 25),
#  ('確定', 24),
#  ('損按', 24),
#  ('所有', 24),
#  ('資訊', 24),
#  ('信用', 23),
#  ('商品', 23),
#  ('表日', 22),
#  ('期間', 22),
#  ('客戶', 22),
#  ('調整', 22),
#  ('原始', 22),
#  ('適用', 21),
#  ('規定', 21),
#  ('營運', 21),
#  ('財務報告', 20),
#  ('包括', 20),
#  ('備供出售', 20),
#  ('租賃', 20),
#  ('政策', 20),
#  ('本期', 20),
#  ('主要', 19),
#  ('帳款', 19),
#  ('預期', 18),
#  ('應收', 18),
#  ('營業', 18),
#  ('分配', 18),
#  ('截至', 18),
#  ('使用', 17),
#  ('決定', 17),
#  ('計畫', 17),
#  ('價值', 17),
#  ('收取', 17),
#  ('個體', 16),
#  ('附註', 16),
#  ('單位', 16),
#  ('發布', 16),
#  ('提供', 16),
#  ('換算', 16),
#  ('差額', 16),
#  ('處分', 16),
#  ('折現', 16),
#  ('分析', 16),
#  ('總額', 15),
#  ('義務', 15),
#  ('符合', 15),
#  ('實現', 15),
#  ('公司債', 15),
#  ('上述', 14),
#  ('之權', 14),
#  ('增加', 14),
#  ('帳面', 14),
#  ('條件', 14),
#  ('短期', 14),
#  ('房及', 14),
#  ('海外', 14),
#  ('投資性', 13),
#  ('基礎', 13),
#  ('國外營運機構', 13),
#  ('任何', 13),
#  ('減少', 13),
#  ('直接', 13),
#  ('合併', 12),
#  ('董事', 12),
#  ('清償', 12),
#  ('會計', 12),
#  ('減除', 12),
#  ('假設', 12),
#  ('收款', 12),
#  ('超過', 12),
#  ('計算', 12),
#  ('情形', 12),
#  ('普通股', 12),
#  ('科技', 12),
#  ('等級', 12),
#  ('模型', 12),
#  ('台安', 11),
#  ('電機', 11),
#  ('提撥', 11),
#  ('外幣', 11),
#  ('建造', 11),
#  ('結果', 11),
#  ('重分', 11),
#  ('編製', 11),
#  ('請詳', 11),
#  ('表達', 11),
#  ('兌換', 11),
#  ('認時', 11),
#  ('可靠', 11),
#  ('情況', 11),
#  ('損損', 11),
#  ('以上', 11),
#  ('資本', 11),
#  ('土地', 11),
#  ('付款', 11),
#  ('盈餘', 11),
#  ('分派', 11),
#  ('暫時性', 11),
#  ('合計', 11),
#  ('投資股', 11),
#  ('以下', 10),
#  ('分為', 10),
#  ('目的', 10),
#  ('予以', 10),
#  ('出售', 10),
#  ('課稅', 10),
#  ('餘額', 10),
#  ('協議', 10),
#  ('方式', 10),
#  ('銷售', 10),
#  ('款項', 10),
#  ('工酬', 10),
#  ('新加坡', 10),
#  ('東安', 10),
#  ('名稱', 10),
#  ('償還', 10),
#  ('憑證', 10),
#  ('每股', 10),
#  ('附表', 10),
#  ('舊及', 9),
#  ('組成', 9),
#  ('之額', 9),
#  ('有關', 9),
#  ('功能性', 9),
#  ('正常', 9),
#  ('產生', 9),
#  ('服務', 9),
#  ('扣除', 9),
#  ('先前', 9),
#  ('完工', 9),
#  ('定期', 9),
#  ('股東', 9),
#  ('技術', 9),
#  ('公司股票', 9),
#  ('工業', 9),
#  ('銀自止', 9),
#  ('票券', 9),
#  ('自止', 9),
#  ('第三', 9),
#  ('修訂', 8),
#  ('認可', 8),
#  ('攤銷', 8),
#  ('方法', 8),
#  ('對價', 8),
#  ('所產生', 8),
#  ('合資', 8),
#  ('所得', 8),
#  ('現值', 8),
#  ('平均', 8),
#  ('商譽', 8),
#  ('十二', 8),
#  ('供交之融', 8),
#  ('帳面額', 8),
#  ('持股', 8),
#  ('法定', 8),
#  ('新股', 8),
#  ('動產廠', 8),
#  ('面額', 8),
#  ('耐用', 8),
#  ('折舊', 8),
#  ('動產', 8),
#  ('準備', 8),
#  ('員工', 8),
#  ('基本', 8),
#  ('收購', 8),
#  ('機構', 8),
#  ('外匯', 8),
#  ('遠期', 8),
#  ('匯風險', 8),
#  ('計折', 8),
#  ('商業', 8),
#  ('實收資本額', 8),
#  ('東華', 8),
#  ('管會', 7),
#  ('事會', 7),
#  ('非融', 7),
#  ('可回收', 7),
#  ('週期', 7),
#  ('改善', 7),
#  ('以及', 7),
#  ('原則', 7),
#  ('分攤', 7),
#  ('移轉', 7),
#  ('總計', 7),
#  ('相同', 7),
#  ('融資', 7),
#  ('依據', 7),
#  ('全部', 7),
#  ('有效', 7),
#  ('當期損', 7),
#  ('已認', 7),
#  ('報酬', 7),
#  ('普通', 7),
#  ('支出', 7),
#  ('根據', 7),
#  ('機關', 7),
#  ('上市', 7),
#  ('收票', 7),
#  ('美國', 7),
#  ('折價', 7),
#  ('盈餘公積', 7),
#  ('青島', 7),
#  ('東元電機', 6),
#  ('經營', 6),
#  ('產品', 6),
#  ('帳戶', 6),
#  ('接受', 6),
#  ('日本公司', 6),
#  ('尚未', 6),
#  ('選擇', 6),
#  ('債務', 6),
#  ('定性', 6),
#  ('時本', 6),
#  ('一致', 6),
#  ('重要', 6),
#  ('過程', 6),
#  ('管階層', 6),
#  ('運用', 6),
#  ('前述', 6),
#  ('報價', 6),
#  ('活絡', 6),
#  ('無法', 6),
#  ('攤銷後成本', 6),
#  ('顯示', 6),
#  ('十三', 6),
#  ('繼續', 6),
#  ('無擔', 6),
#  ('股權', 6),
#  ('房屋', 6),
#  ('以前', 6),
#  ('現產生', 6),
#  ('群組', 6),
#  ('保證', 6),
#  ('特定', 6),
#  ('股票', 6),
#  ('差本', 6),
#  ('經驗', 6),
#  ('用品', 6),
#  ('科技股', 6),
#  ('小計', 6),
#  ('逾期', 6),
#  ('抵呆帳', 6),
#  ('核准', 6),
#  ('日子', 6),
#  ('德高', 6),
#  ('東培', 6),
#  ('之份額', 6),
#  ('台灣', 6),
#  ('淨損', 6),
#  ('性質', 6),
#  ('敏感', 6),
#  ('實業', 6),
#  ('之關', 6),
#  ('西屋', 6),
#  ('歐元', 6),
#  ('第一等', 6),
#  ('入值', 6),
#  ('財務報表', 5),
#  ('簡稱', 5),
#  ('公司法', 5),
#  ('業務', 5),
#  ('機械', 5),
#  ('績效', 5),
#  ('損融', 5),
#  ('是否', 5),
#  ('及合資', 5),
#  ('備抵', 5),
#  ('或務', 5),
#  ('時間', 5),
#  ('認之', 5),
#  ('而產生', 5),
#  ('喪失', 5),
#  ('歸屬', 5),
#  ('條款', 5),
#  ('指定', 5),
#  ('避險', 5),
#  ('客觀', 5),
#  ('證據', 5),
#  ('淨變現價值', 5),
#  ('百分比', 5),
#  ('額則', 5),
#  ('對關', 5),
#  ('該關', 5),
#  ('公積', 5),
#  ('之帳', 5),
#  ('各項', 5),
#  ('同時', 5),
#  ('二十', 5),
#  ('持有人', 5),
#  ('之稅', 5),
#  ('決議', 5),
#  ('稅額', 5),
#  ('之股', 5),
#  ('購者', 5),
#  ('存款', 5),
#  ('性融', 5),
#  ('個別', 5),
#  ('主管', 5),
#  ('私人', 5),
#  ('損總額', 5),
#  ('本票', 5),
#  ('上櫃', 5),
#  ('股仟股', 5),
#  ('東捷', 5),
#  ('江西', 5),
#  ('百分之二十', 5),
#  ('仟元', 4),
#  ('存續', 4),
#  ('通過', 4),
#  ('下表', 4),
#  ('生效日', 4),
#  ('之外', 4),
#  ('避險會計', 4),
#  ('除非', 4),
#  ('保險', 4),
#  ('具有', 4),
#  ('反映', 4),
#  ('時認', 4),
#  ('保盈餘', 4),
#  ('特性', 4),
#  ('衡其', 4),
#  ('此等', 4),
#  ('發人', 4),
#  ('需要', 4),
#  ('經濟', 4),
#  ('即期', 4),
#  ('時將', 4),
#  ('之一', 4),
#  ('用以', 4),
#  ('變動認', 4),
#  ('損對', 4),
#  ('公開', 4),
#  ('息法', 4),
#  ('存在', 4),
#  ('組融', 4),
#  ('困難', 4),
#  ('之現', 4),
#  ('認減', 4),
#  ('未認', 4),
#  ('轉減', 4),
#  ('現時', 4),
#  ('製成品', 4),
#  ('之範圍', 4),
#  ('在建', 4),
#  ('認損', 4),
#  ('享有', 4),
#  ('之會計', 4),
#  ('必要', 4),
#  ('一般', 4),
#  ('推定', 4),
#  ('之減', 4),
#  ('經濟效', 4),
#  ('提折', 4),
#  ('出租', 4),
#  ('時則', 4),
#  ('部門', 4),
#  ('價款', 4),
#  ('及票', 4),
#  ('以淨額', 4),
#  ('簽訂', 4),
#  ('目前', 4),
#  ('實際', 4),
#  ('顧客', 4),
#  ('折扣', 4),
#  ('總價款', 4),
#  ('多項', 4),
#  ('可辨', 4),
#  ('權及', 4),
#  ('判斷', 4),
#  ('因素', 4),
#  ('未有', 4),
#  ('其中', 4),
#  ('日動', 4),
#  ('授信', 4),
#  ('之融', 4),
#  ('日本', 4),
#  ('預計', 4),
#  ('發股', 4),
#  ('以現', 4),
#  ('價格', 4),
#  ('擔保品', 4),
#  ('一次', 4),
#  ('額分別', 4),
#  ('日餘額', 4),
#  ('在外', 4),
#  ('表彰', 4),
#  ('轉投資', 4),
#  ('事業', 4),
#  ('董監酬', 4),
#  ('未實', 4),
#  ('扣抵', 4),
#  ('加權', 4),
#  ('西亞', 4),
#  ('香港', 4),
#  ('馬達', 4),
#  ('廈門', 4),
#  ('創新', 4),
#  ('雙方議', 4),
#  ('定並', 4),
#  ('票據', 4),
#  ('資貸', 4),
#  ('人民', 4),
#  ('適當', 4),
#  ('風險本', 4),
#  ('因此', 4),
#  ('日圓', 4),
#  ('到期日', 4),
#  ('第二', 4),
#  ('缺乏', 4),
#  ('通性', 4),
#  ('電子', 3),
#  ('另本', 3),
#  ('本個體', 3),
#  ('日經', 3),
#  ('計處', 3),
#  ('闡釋', 3),
#  ('單獨', 3),
#  ('並無', 3),
#  ('第號融', 3),
#  ('撤銷', 3),
#  ('模式', 3),
#  ('顯著', 3),
#  ('之分', 3),
#  ('首次', 3),
#  ('公告', 3),
#  ('辨認', 3),
#  ('版本', 3),
#  ('調增', 3),
#  ('完成', 3),
#  ('承租人', 3),
#  ('出租人', 3),
#  ('權權', 3),
#  ('還款', 3),
#  ('投資者', 3),
#  ('或合', 3),
#  ('之長', 3),
#  ('抵減', 3),
#  ('認及', 3),
#  ('證券', 3),
#  ('衡之', 3),
#  ('之淨額', 3),
#  ('涉及', 3),
#  ('作為', 3),
#  ('交及', 3),
#  ('匯評', 3),
#  ('價調', 3),
#  ('整因', 3),
#  ('屬合', 3),
#  ('之合', 3),
#  ('之非', 3),
#  ('期末', 3),
#  ('標準', 3),
#  ('持有者', 3),
#  ('清償者', 3),
#  ('交付', 3),
#  ('交割', 3),
#  ('一項', 3),
#  ('未現', 3),
#  ('債務人', 3),
#  ('違約', 3),
#  ('該融', 3),
#  ('收回', 3),
#  ('大幅', 3),
#  ('之限額', 3),
#  ('現之', 3),
#  ('十一', 3),
#  ('直線法', 3),
#  ('存貨', 3),
#  ('比較', 3),
#  ('特別', 3),
#  ('工作', 3),
#  ('已發', 3),
#  ('進請', 3),
#  ('款額', 3),
#  ('十四', 3),
#  ('損業', 3),
#  ('損份額', 3),
#  ('損份', 3),
#  ('失份額', 3),
#  ('或間', 3),
#  ('損及', 3),
#  ('認購', 3),
#  ('損之', 3),
#  ('自權', 3),
#  ('母公司', 3),
#  ('變動則', 3),
#  ('建築', 3),
#  ('機器', 3),
#  ('運輸', 3),
#  ('額低', 3),
#  ('項並', 3),
#  ('時始', 3),
#  ('及融', 3),
#  ('通期', 3),
#  ('二十七', 3),
#  ('政府', 3),
#  ('之應', 3),
#  ('估計時', 3),
#  ('估額', 3),
#  ('損或', 3),
#  ('淨額', 3),
#  ('同一', 3),
#  ('股本', 3),
#  ('減項', 3),
#  ('現股', 3),
#  ('空調', 3),
#  ('購買', 3),
#  ('預估', 3),
#  ('基準', 3),
#  ('估計及', 3),
#  ('持續', 3),
#  ('分散', 3),
#  ('專戶', 3),
#  ('從事', 3),
#  ('規避', 3),
#  ('損之額', 3),
#  ('擔保', 3),
#  ('非避險', 3),
#  ('公平', 3),
#  ('非上市', 3),
#  ('依據本', 3),
#  ('之信', 3),
#  ('質資訊', 3),
#  ('帳齡', 3),
#  ('據及', 3),
#  ('減備', 3),
#  ('失減', 3),
#  ('組群', 3),
#  ('開發', 3),
#  ('管股', 3),
#  ('世正開', 3),
#  ('小計關', 3),
#  ('昌電子', 3),
#  ('風電股', 3),
#  ('新能', 3),
#  ('限制', 3),
#  ('他人', 3),
#  ('區間', 3),
#  ('國內', 3),
#  ('票面', 3),
#  ('固定', 3),
#  ('瑞穗', 3),
#  ('中華', 3),
#  ('還無台灣', 3),
#  ('設定', 3),
#  ('辦法', 3),
#  ('服務資', 3),
#  ('薪資', 3),
#  ('基投資', 3),
#  ('私募', 3),
#  ('未薪資', 3),
#  ('稀釋', 3),
#  ('事項', 3),
#  ('法及', 3),
#  ('原有', 3),
#  ('買入', 3),
#  ('發給', 3),
#  ('虧損', 3),
#  ('成長', 3),
#  ('運費', 3),
#  ('高估', 3),
#  ('之潛', 3),
#  ('之影響', 3),
#  ('機電', 3),
#  ('安台', 3),
#  ('服務股', 3),
#  ('東訊', 3),
#  ('發展', 3),
#  ('無錫東元', 3),
#  ('東成', 3),
#  ('無錫', 3),
#  ('食品', 3),
#  ('背書', 3),
#  ('服務費', 3),
#  ('風險管', 3),
#  ('整體', 3),
#  ('預測', 3),
#  ('匯波動', 3),
#  ('浮動', 3),
#  ('模擬', 3),
#  ('方案', 3),
#  ('日認', 3),
#  ('三億元', 3),
#  ('電器', 2),
#  ('消滅', 2),
#  ('安陽', 2),
#  ('東台', 2),
#  ('科技股份', 2),
#  ('管委', 2),
#  ('員會', 2),
#  ('揭倡議', 2),
#  ('及第', 2),
#  ('號之', 2),
#  ('所述', 2),
#  ('未實現', 2),
#  ('取代', 2),
#  ('表示', 2),
#  ('此準則', 2),
#  ('核心', 2),
#  ('有權', 2),
#  ('中之約', 2),
#  ('義務步', 2),
#  ('交價格', 2),
#  ('滿足', 2),
#  ('使用者', 2),
#  ('如何', 2),
#  ('負責', 2),
#  ('表受', 2),
#  ('適用額', 2),
#  ('升級', 2),
#  ('影響額', 2),
#  ('額明', 2),
#  ('調減', 2),
#  ('權並', 2),
#  ('因子', 2),
#  ('投入', 2),
#  ('第號確', 2),
#  ('存有', 2),
#  ('報導', 2),
#  ('遵循', 2),
#  ('其判斷', 2),
#  ('以本', 2),
#  ('所處', 2),
#  ('環境', 2),
#  ('衡本', 2),
#  ('交日', 2),
#  ('損外幣', 2),
#  ('衡者', 2),
#  ('差額認', 2),
#  ('損表', 2),
#  ('及損', 2),
#  ('及合', 2),
#  ('表之', 2),
#  ('收及', 2),
#  ('費損', 2),
#  ('比重', 2),
#  ('損作', 2),
#  ('部份', 2),
#  ('即使', 2),
#  ('仍保', 2),
#  ('權但', 2),
#  ('比將', 2),
#  ('當本', 2),
#  ('分為動', 2),
#  ('預期將', 2),
#  ('期中', 2),
#  ('為交', 2),
#  ('至少', 2),
#  ('除外', 2),
#  ('期限', 2),
#  ('隨時', 2),
#  ('定期存款', 2),
#  ('交慣', 2),
#  ('交日會計', 2),
#  ('衡相', 2),
#  ('關交', 2),
#  ('則認', 2),
#  ('損續', 2),
#  ('衡續', 2),
#  ('衡時', 2),
#  ('放款', 2),
#  ('及應', 2),
#  ('衡後續採', 2),
#  ('之額衡', 2),
#  ('付息', 2),
#  ('發票', 2),
#  ('額衡', 2),
#  ('認後發生', 2),
#  ('失事', 2),
#  ('或法', 2),
#  ('給予', 2),
#  ('可能性', 2),
#  ('別融', 2),
#  ('持久性', 2),
#  ('下跌', 2),
#  ('轉認', 2),
#  ('失之額', 2),
#  ('藉由', 2),
#  ('分至', 2),
#  ('之除', 2),
#  ('除融', 2),
#  ('已移', 2),
#  ('誘因', 2),
#  ('平均法', 2),
#  ('尚須', 2),
#  ('議定', 2),
#  ('結束', 2),
#  ('回收', 2),
#  ('內認', 2),
#  ('之變', 2),
#  ('生成', 2),
#  ('認潤', 2),
#  ('之個體', 2),
#  ('結構', 2),
#  ('交所產生', 2),
#  ('已作', 2),
#  ('損如本', 2),
#  ('認之損', 2),
#  ('表決權', 2),
#  ('任一', 2),
#  ('之損', 2),
#  ('保之應', 2),
#  ('認進', 2),
#  ('一步', 2),
#  ('已代其', 2),
#  ('支付款', 2),
#  ('比銷', 2),
#  ('致使', 2),
#  ('損者', 2),
#  ('認之額', 2),
#  ('轉出', 2),
#  ('損失則', 2),
#  ('失本', 2),
#  ('十五', 2),
#  ('為入', 2),
#  ('帳基礎', 2),
#  ('維修', 2),
#  ('之後續', 2),
#  ('衡採', 2),
#  ('限以', 2),
#  ('殘值', 2),
#  ('十七', 2),
#  ('十八', 2),
#  ('無形資產', 2),
#  ('使用期', 2),
#  ('十九', 2),
#  ('額當', 2),
#  ('高者', 2),
#  ('測試', 2),
#  ('回價值', 2),
#  ('提取', 2),
#  ('二十一', 2),
#  ('之義務', 2),
#  ('二十二', 2),
#  ('二十三', 2),
#  ('二十四', 2),
#  ('意圖', 2),
#  ('表中', 2),
#  ('二十五', 2),
#  ('發之', 2),
#  ('修改', 2),
#  ('給付', 2),
#  ('最佳', 2),
#  ('事件', 2),
#  ('資源', 2),
#  ('義務且', 2),
#  ('該義務', 2),
#  ('二十八', 2),
#  ('預付', 2),
#  ('淨義務', 2),
#  ('日前', 2),
#  ('終止', 2),
#  ('董監', 2),
#  ('實際配', 2),
#  ('發額', 2),
#  ('二十九', 2),
#  ('入權', 2),
#  ('損本', 2),
#  ('所在', 2),
#  ('已法', 2),
#  ('實質', 2),
#  ('並在', 2),
#  ('稅捐', 2),
#  ('股東會', 2),
#  ('差認', 2),
#  ('源自', 2),
#  ('予認', 2),
#  ('可以', 2),
#  ('當有', 2),
#  ('執權', 2),
#  ('抵且', 2),
#  ('將當期', 2),
#  ('互抵', 2),
#  ('主體', 2),
#  ('三十', 2),
#  ('三十二', 2),
#  ('活動', 2),
#  ('增值', 2),
#  ('退回', 2),
#  ('銷貨', 2),
#  ('法認', 2),
#  ('可單', 2),
#  ('額並', 2),
#  ('以個', 2),
#  ('清算', 2),
#  ('及承擔', 2),
#  ('設確', 2),
#  ('作出', 2),
#  ('導致', 2),
#  ('之明', 2),
#  ('權投資', 2),
#  ('別權', 2),
#  ('及額', 2),
#  ('自用', 2),
#  ('科目', 2),
#  ('用途', 2),
#  ('失分', 2),
#  ('之交及', 2),
#  ('資訊明', 2),
#  ('質押', 2),
#  ('之該', 2),
#  ('名目', 2),
#  ('評價調', 2),
#  ('關本', 2),
#  ('五應收', 2),
#  ('已減', 2),
#  ('失合', 2),
#  ('計月', 2),
#  ('未減', 2),
#  ('控管', 2),
#  ('計及', 2),
#  ('原物', 2),
#  ('途存', 2),
#  ('貨月', 2),
#  ('積已', 2),
#  ('別工', 2),
#  ('小計合', 2),
#  ('資新能', 2),
#  ('歐洲德', 2),
#  ('各該', 2),
#  ('投資餘額', 2),
#  ('母子公司', 2),
#  ('總性', 2),
#  ('營業場', 2),
#  ('日關', 2),
#  ('之性', 2),
#  ('質衡', 2),
#  ('占關', 2),
#  ('商譽關', 2),
#  ('損表本', 2),
#  ('東元茂迪股', 2),
#  ('損稅後淨額', 2),
#  ('自關', 2),
#  ('風電', 2),
#  ('稅前', 2),
#  ('增添', 2),
#  ('資本化額', 2),
#  ('第一', 2),
#  ('抵押', 2),
#  ('建築合計', 2),
#  ('動產之租', 2),
#  ('日區間', 2),
#  ('第一次', 2),
#  ('發條件', 2),
#  ('募集', 2),
#  ('發國內', 2),
#  ('第一期', 2),
#  ('發總額計', 2),
#  ('發期間', 2),
#  ('按債', 2),
#  ('券面', 2),
#  ('日發', 2),
#  ('日長', 2),
#  ('期銀', 2),
#  ('匯豐', 2),
#  ('三井', 2),
#  ('住友', 2),
#  ('還無應付', 2),
#  ('還無萬通', 2),
#  ('還無減', 2),
#  ('要求', 2),
#  ('一定', 2),
#  ('施工', 2),
#  ('每滿', 2),
#  ('再衡', 2),
#  ('帳上', 2),
#  ('收支', 2),
#  ('存放', 2),
#  ('投資國', 2),
#  ('依當', 2),
#  ('按照', 2),
#  ('地區', 2),
#  ('之員', 2),
#  ('工個', 2),
#  ('及本', 2),
#  ('增資發', 2),
#  ('證發', 2),
#  ('之經營', 2),
#  ('兌回', 2),
#  ('依中華', 2),
#  ('請求', 2),
#  ('價證券', 2),
#  ('優先', 2),
#  ('明細', 2),
#  ('之比', 2),
#  ('百分之十', 2),
#  ('得以', 2),
#  ('依本', 2),
#  ('公司章程', 2),
#  ('盈餘中', 2),
#  ('發放', 2),
#  ('百分之八十', 2),
#  ('百分之五十', 2),
#  ('股市', 2),
#  ('價元', 2),
#  ('股東安', 2),
#  ('投資安台', 2),
#  ('百分之五', 2),
#  ('借方', 2),
#  ('提特別', 2),
#  ('日融', 2),
#  ('現損', 2),
#  ('災害', 2),
#  ('尚有', 2),
#  ('盈餘加', 2),
#  ('時性', 2),
#  ('認於損', 2),
#  ('現銷', 2),
#  ('貨毛', 2),
#  ('限財稅', 2),
#  ('差未', 2),
#  ('永久性', 2),
#  ('跌價存', 2),
#  ('貨跌', 2),
#  ('價備', 2),
#  ('超限', 2),
#  ('國外', 2),
#  ('投資收', 2),
#  ('土地增值', 2),
#  ('稅準備', 2),
#  ('並未', 2),
#  ('營事業', 2),
#  ('公布', 2),
#  ('生效', 2),
#  ('此稅', 2),
#  ('通稅後額', 2),
#  ('盈餘元', 2),
#  ('淨稀釋', 2),
#  ('盈餘具', 2),
#  ('作用', 2),
#  ('影響員', 2),
#  ('淨加', 2),
#  ('東元米', 2),
#  ('東勝', 2),
#  ('電機股', 2),
#  ('東泰榮', 2),
#  ('比克', 2),
#  ('電股', 2),
#  ('高安', 2),
#  ('越南', 2),
#  ('捷德', 2),
#  ('家電', 2),
#  ('東慧', 2),
#  ('加拿大', 2),
#  ('南昌', 2),
#  ('安元', 2),
#  ('自動化', 2),
#  ('優捷', 2),
#  ('澳洲', 2),
#  ('四川', 2),
#  ('台科', 2),
#  ('印尼', 2),
#  ('總合', 2),
#  ('上海', 2),
#  ('土耳其', 2),
#  ('湖南', 2),
#  ('東興', 2),
#  ('天津', 2),
#  ('東資', 2),
#  ...]

# %%
font = "/System/Library/Fonts/PingFang.ttc"
wordcloud = WordCloud(background_color="white",width=2000, height=1000, margin=2,font_path=font)
wordcloud.fit_words(wordDict)
plt.imshow(wordcloud)
wordcloud.to_file('week4_wordcloud.png')

# %%
data = []
for t in ten[:10]:
    data.append(t[1])
label = []
for t in ten[:10]:
    label.append(t[0])

# %%
plt.rcParams["font.sans-serif"]=["SimHei"]
plt.figure(figsize=(15,8))
plt.bar(range(0,10),data)
plt.xticks(range(0,10),label,fontsize=20)
plt.savefig("week4_plt.png")
